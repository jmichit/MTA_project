# %% [markdown]
# ## MTA Transit MVP

# %% [markdown]
# ### Client has revised the "ask"

# %% [markdown]
# Originally the client was open with just finding the highest traffic areas but after furthe discussion decided to narrow the search to the borough of Queens, both to avoid high traffic Manhattan stops (with many suburb commuters) and to focus more on the local population

# %% [markdown]
# Graph below shows preliminary high traffic (both entries and exits) in Queens with further suggestions of day of week / time of day to be added for final proposal

# %%
import pandas as pd

import matplotlib.pyplot as plt

x = plt.imread("hightrafficQ.png")

plt.imshow(x)
